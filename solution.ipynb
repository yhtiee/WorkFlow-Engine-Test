# %%
Subscribers = [{"john@email.com":{"signedin": True}}, {"sam@email.com" :{"signedin": True}}, {"philip@email.com":{ "signedin": False}}, {"great@email.com":{"signedin": True}}, {"jake@email.com":{"signedin": False}}]

Emails = ["john@email.com", "sam@email.com", "philip@email.com", "great@email.com", "jake@email.com"]

Add_to_list_Action = []

Signed_in_Subscribers = []

# %%
import datetime

# %%
# Triggers 
from datetime import time, timezone
from select import select
from time import sleep

print("WELCOME TO WORKFLOW ENGINE")
print(" Welcome to Triggers Section Please select:\n 1 for Opt-in Trigger\n 2 for Time Trigger\n 3 for Campaign Trigger\n 4 for Removed from List Trigger\n 5 for Purchase Activity Trigger\n 6 for Page Visited Trigger\n 7 for Register Webinar or Attend Webinar")

Trigger_request = int(input("Welcome Please Check the Output to Select an A Trigger Option With Number Attached:"))
if Trigger_request == 1:
        print()
        print("The Opt-In Trigger has been Triggered Please Continue with your Work Flow")
        for x in Subscribers:
            for key,value in x.items():
                for key2, value2 in value.items():
                    if value2 == True:
                        Signed_in_Subscribers.append(x)

        print("Please Select Conditions to Pass Subriber for Futher Actions If the Meet The Condition:\n 1 for Campaign Status Condition\n 2 for On List or Segment Condition\n 3 for Has Visited Page Condition\n 4 for Check List Field Condition\n 5 for Purchase Status Condition \n 6 for Check Webinar Status Condition")

        condition_request = int(input("Welcome Please Check the Output to Select a Condition to Apply With Number Attached:"))

        if condition_request == 1:
            print("Check for Campaign Status Selected\n")

            print("Please Select any Email:\n 1 for john@email.com \n 2 for sam@email.com \n 3 for great@email.com\n 4 for philip@email.com\n 5 for jake@email.com")
            select_email = int(input("Welcome Please Check the Output to Select an Email With Number Attached"))
            if select_email == 1:
                email = "john@email.com"
                if email in Signed_in_Subscribers:
                    for x in Signed_in_Subscribers:
                        for key, value in x.items():
                            if key == email:
                                val = x[key]
                                for key2 in val.keys():
                                    if "Campaign_Status" in val:

                                        print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                                        action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                                        if action_Request == 1:
                                            print()
                                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                                            def Send_email():
                                                pass
                                        
                                        elif action_Request == 2:
                                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                                            sleep(set_time)
                                            print()
                                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                                            def Add_Delay():
                                                email_message = {"message": "I am sending an email message"}
                                                return (f"An email {email_message} has been sent to {email}\n")
                                                            
                                        elif action_Request== 3:
                                            def Add_to_List():
                                                Add_to_list_Action.append(email)
                                                return (f"Subscriber Added to List {Add_to_list_Action}")

                                        elif action_Request == 4:
                                            def Remove_from_List():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == email:
                                                            removed_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                                        elif action_Request == 5:
                                            def Eject_from_Journey():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == email:
                                                            ejected_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                                        elif action_Request == 6:
                                            def Apply_or_Remove_Tags():
                                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                                if select_choice == 1:
                                                    add_tag = input("Please add a tag: e.g Marketing")
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == email:
                                                                value["Tags"] = {"tag1":add_tag}
                                                            else:
                                                                return ("Invalid Subscriber")
                                                    return(f"Tag added to Subscriber {email}, {Subscribers}")

                                                elif select_choice == 2:
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == email:
                                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                                        
                                                                for key2, value2 in value.items():
                                                                    if value2 == select_tag_to_remove:
                                                                        del value[key2] 
                                                                    else:
                                                                        return ("Tag dosent exist")
                                                            else:
                                                                return("Invalid Subscriber")

                                        elif action_Request == 7:
                                            def Auto_Register():
                                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                                for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == email:
                                                                value["Webinar_Platform"] = "GotoWebinar"
                                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                                            else:
                                                                return("Invalid Subscriber")        
                                        else:
                                            print("invalid selection please choose a valid input")    
                                            pass
                                    else:
                                        print("No Campaign_Status Detected")
                else:
                    print("User Not Signed_In")

            elif select_email == 2:
                email = "sam@email.com"
                if email in Signed_in_Subscribers:
                    for x in Signed_in_Subscribers:
                        for key, value in x.items():
                            if key == email:
                                val = x[key]
                                for key2 in val.keys():
                                    if "Campaign_Status" in val:

                                        print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                                        action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                                        if action_Request == 1:
                                            print()
                                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                                            def Send_email():
                                                pass
                                        
                                        elif action_Request == 2:
                                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                                            sleep(set_time)
                                            print()
                                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                                            def Add_Delay():
                                                email_message = {"message": "I am sending an email message"}
                                                return (f"An email {email_message} has been sent to {email}\n")
                                                            
                                        elif action_Request== 3:
                                            def Add_to_List():
                                                Add_to_list_Action.append(email)
                                                return (f"Subscriber Added to List {Add_to_list_Action}")

                                        elif action_Request == 4:
                                            def Remove_from_List():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == email:
                                                            removed_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                                        elif action_Request == 5:
                                            def Eject_from_Journey():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == email:
                                                            ejected_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                                        elif action_Request == 6:
                                            def Apply_or_Remove_Tags():
                                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                                if select_choice == 1:
                                                    add_tag = input("Please add a tag: e.g Marketing")
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == email:
                                                                value["Tags"] = {"tag1":add_tag}
                                                            else:
                                                                return ("Invalid Subscriber")
                                                    return(f"Tag added to Subscriber {email}, {Subscribers}")

                                                elif select_choice == 2:
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == email:
                                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                                        
                                                                for key2, value2 in value.items():
                                                                    if value2 == select_tag_to_remove:
                                                                        del value[key2] 
                                                                    else:
                                                                        return ("Tag dosent exist")
                                                            else:
                                                                return("Invalid Subscriber")
                                                                
                                        elif action_Request == 7:
                                            def Auto_Register():
                                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                                for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == email:
                                                                value["Webinar_Platform"] = "GotoWebinar"
                                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                                            else:
                                                                return("Invalid Subscriber")        
                                        else:
                                            print("invalid selection please choose a valid input")    
                                            pass
                                    else:
                                        print("No Campaign_Status Detected")
                else:
                    print("User Not Signed_In")


            elif select_email == 3:
                email = "great@email.com"
                if email in Signed_in_Subscribers:
                    for x in Signed_in_Subscribers:
                        for key, value in x.items():
                            if key == email:
                                val = x[key]
                                for key2 in val.keys():
                                    if "Campaign_Status" in val:

                                        print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                                        action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                                        if action_Request == 1:
                                            print()
                                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                                            def Send_email():
                                                pass
                                        
                                        elif action_Request == 2:
                                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                                            sleep(set_time)
                                            print()
                                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                                            def Add_Delay():
                                                email_message = {"message": "I am sending an email message"}
                                                return (f"An email {email_message} has been sent to {email}\n")
                                                            
                                        elif action_Request== 3:
                                            def Add_to_List():
                                                Add_to_list_Action.append(email)
                                                return (f"Subscriber Added to List {Add_to_list_Action}")

                                        elif action_Request == 4:
                                            def Remove_from_List():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == email:
                                                            removed_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                                        elif action_Request == 5:
                                            def Eject_from_Journey():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == email:
                                                            ejected_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                                        elif action_Request == 6:
                                            def Apply_or_Remove_Tags():
                                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                                if select_choice == 1:
                                                    add_tag = input("Please add a tag: e.g Marketing")
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == email:
                                                                value["Tags"] = {"tag1":add_tag}
                                                            else:
                                                                return ("Invalid Subscriber")
                                                    return(f"Tag added to Subscriber {email}, {Subscribers}")

                                                elif select_choice == 2:
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == email:
                                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                                        
                                                                for key2, value2 in value.items():
                                                                    if value2 == select_tag_to_remove:
                                                                        del value[key2] 
                                                                    else:
                                                                        return ("Tag dosent exist")
                                                            else:
                                                                return("Invalid Subscriber")
                                                                
                                        elif action_Request == 7:
                                            def Auto_Register():
                                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                                for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == email:
                                                                value["Webinar_Platform"] = "GotoWebinar"
                                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                                            else:
                                                                return("Invalid Subscriber")        
                                        else:
                                            print("invalid selection please choose a valid input")    
                                            pass
                                    else:
                                        print("No Campaign_Status Detected")
                else:
                    print("User Not Signed_In")

            elif select_email == 4:
                email = "philip@email.com"
                if email in Signed_in_Subscribers:
                    for x in Signed_in_Subscribers:
                        for key, value in x.items():
                            if key == email:
                                val = x[key]
                                for key2 in val.keys():
                                    if "Campaign_Status" in val:

                                        print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                                        action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                                        if action_Request == 1:
                                            print()
                                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                                            def Send_email():
                                                pass
                                        
                                        elif action_Request == 2:
                                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                                            sleep(set_time)
                                            print()
                                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                                            def Add_Delay():
                                                email_message = {"message": "I am sending an email message"}
                                                return (f"An email {email_message} has been sent to {email}\n")
                                                            
                                        elif action_Request== 3:
                                            def Add_to_List():
                                                Add_to_list_Action.append(email)
                                                return (f"Subscriber Added to List {Add_to_list_Action}")

                                        elif action_Request == 4:
                                            def Remove_from_List():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == email:
                                                            removed_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                                        elif action_Request == 5:
                                            def Eject_from_Journey():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == email:
                                                            ejected_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                                        elif action_Request == 6:
                                            def Apply_or_Remove_Tags():
                                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                                if select_choice == 1:
                                                    add_tag = input("Please add a tag: e.g Marketing")
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == email:
                                                                value["Tags"] = {"tag1":add_tag}
                                                            else:
                                                                return ("Invalid Subscriber")
                                                    return(f"Tag added to Subscriber {email}, {Subscribers}")

                                                elif select_choice == 2:
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == email:
                                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                                        
                                                                for key2, value2 in value.items():
                                                                    if value2 == select_tag_to_remove:
                                                                        del value[key2] 
                                                                    else:
                                                                        return ("Tag dosent exist")
                                                            else:
                                                                return("Invalid Subscriber")
                                                                
                                        elif action_Request == 7:
                                            def Auto_Register():
                                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                                for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == email:
                                                                value["Webinar_Platform"] = "GotoWebinar"
                                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                                            else:
                                                                return("Invalid Subscriber")        
                                        else:
                                            print("invalid selection please choose a valid input")    
                                            pass
                                    else:
                                        print("No Campaign_Status Detected")
                else:
                    print("User Not Signed_In")

            elif select_email == 5:
                email = "jake@email.com"
                if email in Signed_in_Subscribers:
                    for x in Signed_in_Subscribers:
                        for key, value in x.items():
                            if key == email:
                                val = x[key]
                                for key2 in val.keys():
                                    if "Campaign_Status" in val:

                                       print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                                       action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                                       if action_Request == 1:
                                            print()
                                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                                            def Send_email():
                                                pass
                                        
                                       elif action_Request == 2:
                                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                                            sleep(set_time)
                                            print()
                                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                                            def Add_Delay():
                                                email_message = {"message": "I am sending an email message"}
                                                return (f"An email {email_message} has been sent to {email}\n")
                                                            
                                       elif action_Request== 3:
                                            def Add_to_List():
                                                Add_to_list_Action.append(email)
                                                return (f"Subscriber Added to List {Add_to_list_Action}")

                                       elif action_Request == 4:
                                            def Remove_from_List():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == email:
                                                            removed_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                                       elif action_Request == 5:
                                            def Eject_from_Journey():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == email:
                                                            ejected_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                                       elif action_Request == 6:
                                            def Apply_or_Remove_Tags():
                                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                                if select_choice == 1:
                                                    add_tag = input("Please add a tag: e.g Marketing")
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == email:
                                                                value["Tags"] = {"tag1":add_tag}
                                                            else:
                                                                return ("Invalid Subscriber")
                                                    return(f"Tag added to Subscriber {email}, {Subscribers}")

                                                elif select_choice == 2:
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == email:
                                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                                        
                                                                for key2, value2 in value.items():
                                                                    if value2 == select_tag_to_remove:
                                                                        del value[key2] 
                                                                    else:
                                                                        return ("Tag dosent exist")
                                                            else:
                                                                return("Invalid Subscriber")
                                                                
                                       elif action_Request == 7:
                                            def Auto_Register():
                                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                                for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == email:
                                                                value["Webinar_Platform"] = "GotoWebinar"
                                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                                            else:
                                                                return("Invalid Subscriber")        
                                       else:
                                            print("invalid selection please choose a valid input")    
                                            pass
                                else:
                                    print("No Campaign_Status Detected")
                else:
                    print("User Not Signed_In")

        elif condition_request == 2:
            
            print("Please Select any List to Check On List Condition:\n 1 for Subscribers List \n 2 for Emails List \n 3 for Add_To_List_Action_list\n 4 for Signed_in_Subscribers_List")

            select_list = int(input("Welcome Please Check the Output to Select a List With Number Attached"))
            if select_list == 1:
            
                select_status = int(input("Please select Status: 1 for Is on List or 2 for Is not on List"))

                if select_status == 1:
                    print("Please Select any Subscriber:\n 1 for john@email.com \n 2 for sam@email.com \n 3 for great@email.com\n 4 for philip@email.com\n 5 for jake@email.com")
                    select_subcriber = input("Please select subscriber by inputing his email to check if he is on list e.g great@gmail.com")

                    for x in Subscribers:
                        for key , value in x.items():
                            if key == select_subcriber:
                                print("Subscriber is on List")
                                print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                                action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                                if action_Request == 1:
                                    print()
                                    print("The Send Email Action has Completed Please Continue with your Work Flow")
                                    def Send_email():
                                        pass
                                
                                elif action_Request == 2:
                                    set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                                    sleep(set_time)
                                    print()
                                    print("The Add Delay Action has Completed Please Continue with your Work Flow")
                                    def Add_Delay(select_subcriber):
                                        email_message = {"message": "I am sending an email message"}
                                        print(f"An email {email_message} has been sent to {select_subcriber}\n")
                                        
                                    Add_Delay(select_subcriber)
                                                    
                                elif action_Request== 3:
                                    def Add_to_List():
                                        Add_to_list_Action.append(select_subcriber)
                                        return (f"Subscriber Added to List {Add_to_list_Action}")

                                elif action_Request == 4:
                                    def Remove_from_List():
                                        for x in range(len(Subscribers)):
                                            for key, value in Subscribers[x].items():
                                                if key == select_subcriber:
                                                    removed_subscriber = Subscribers.pop(x)
                                        return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                                elif action_Request == 5:
                                    def Eject_from_Journey():
                                        for x in range(len(Subscribers)):
                                            for key, value in Subscribers[x].items():
                                                if key == select_subcriber:
                                                    ejected_subscriber = Subscribers.pop(x)
                                        return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                                elif action_Request == 6:
                                    def Apply_or_Remove_Tags():
                                        select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                        if select_choice == 1:
                                            add_tag = input("Please add a tag: e.g Marketing")
                                            for x in Subscribers:
                                                for key, value in x.items():
                                                    if key == select_subcriber:
                                                        value["Tags"] = {"tag1":add_tag}
                                                    else:
                                                        return ("Invalid Subscriber")
                                            return(f"Tag added to Subscriber {select_subcriber}, {Subscribers}")

                                        elif select_choice == 2:
                                            for x in Subscribers:
                                                for key, value in x.items():
                                                    if key == select_subcriber:
                                                        select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                                
                                                        for key2, value2 in value.items():
                                                            if value2 == select_tag_to_remove:
                                                                del value[key2] 
                                                            else:
                                                                return ("Tag dosent exist")
                                                    else:
                                                        return("Invalid Subscriber")
                                                        
                                elif action_Request == 7:
                                    def Auto_Register():
                                        add_upcoming_webinar = input("Please add any upcoming webinar")
                                        for x in Subscribers:
                                                for key, value in x.items():
                                                    if key == select_subcriber:
                                                        value["Webinar_Platform"] = "GotoWebinar"
                                                        value["Upcoming_Webinar"] = add_upcoming_webinar
                                                    else:
                                                        return("Invalid Subscriber")        
                                else:
                                    print("invalid selection please choose a valid input")

                elif select_status == 2:
                    print("Please Select any Subscriber:\n 1 for john@email.com \n 2 for sam@email.com \n 3 for great@email.com\n 4 for philip@email.com\n 5 for jake@email.com")
                    select_subcriber = input("Please select subscriber by inputing his email to check if he is on list e.g great@gmail.com")

                    for x in Subscribers:
                        for key , value in x.items():
                            if key != select_subcriber:
                                print("User not on list")

            elif select_list == 2:
                select_status = int(input("Please select Status: 1 for Is on List or 2 for Is not on List"))

                if select_status == 1:
                    print("Please Select any Subscriber:\n 1 for john@email.com \n 2 for sam@email.com \n 3 for great@email.com\n 4 for philip@email.com\n 5 for jake@email.com")

                    select_subcriber = input("Please select subscriber by inputing his email to check if he is on list e.g great@gmail.com")

                    if select_subcriber in Emails:
                        print("Subscriber is on List")
                        print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                        action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                        if action_Request == 1:
                            print()
                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                            def Send_email():
                                pass
                        
                        elif action_Request == 2:
                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                            sleep(set_time)
                            print()
                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                            def Add_Delay():
                                email_message = {"message": "I am sending an email message"}
                                return (f"An email {email_message} has been sent to {select_subcriber}\n")
                                            
                        elif action_Request== 3:
                            def Add_to_List():
                                Add_to_list_Action.append(select_subcriber)
                                return (f"Subscriber Added to List {Add_to_list_Action}")

                        elif action_Request == 4:
                            def Remove_from_List():
                                for x in range(len(Subscribers)):
                                    for key, value in Subscribers[x].items():
                                        if key == select_subcriber:
                                            removed_subscriber = Subscribers.pop(x)
                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                        elif action_Request == 5:
                            def Eject_from_Journey():
                                for x in range(len(Subscribers)):
                                    for key, value in Subscribers[x].items():
                                        if key == select_subcriber:
                                            ejected_subscriber = Subscribers.pop(x)
                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                        elif action_Request == 6:
                            def Apply_or_Remove_Tags():
                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                if select_choice == 1:
                                    add_tag = input("Please add a tag: e.g Marketing")
                                    for x in Subscribers:
                                        for key, value in x.items():
                                            if key == select_subcriber:
                                                value["Tags"] = {"tag1":add_tag}
                                            else:
                                                return ("Invalid Subscriber")
                                    return(f"Tag added to Subscriber {select_subcriber}, {Subscribers}")

                                elif select_choice == 2:
                                    for x in Subscribers:
                                        for key, value in x.items():
                                            if key == select_subcriber:
                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                        
                                                for key2, value2 in value.items():
                                                    if value2 == select_tag_to_remove:
                                                        del value[key2] 
                                                    else:
                                                        return ("Tag dosent exist")
                                            else:
                                                return("Invalid Subscriber")
                                                
                        elif action_Request == 7:
                            def Auto_Register():
                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                for x in Subscribers:
                                        for key, value in x.items():
                                            if key == select_subcriber:
                                                value["Webinar_Platform"] = "GotoWebinar"
                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                            else:
                                                return("Invalid Subscriber")        
                        else:
                            print("invalid selection please choose a valid input")

            elif select_list == 3:
                select_status = int(input("Please select Status: 1 for Is on List or 2 for Is not on List"))

                if select_status == 1:
                    print("Please Select any Subscriber:\n 1 for john@email.com \n 2 for sam@email.com \n 3 for great@email.com\n 4 for philip@email.com\n 5 for jake@email.com")

                    select_subcriber = input("Please select subscriber by inputing his email to check if he is on list e.g great@gmail.com")

                    if select_subcriber in Add_to_list_Action:
                        print("Subscriber is on List")
                        print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                        action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                        if action_Request == 1:
                            print()
                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                            def Send_email():
                                pass
                        
                        elif action_Request == 2:
                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                            sleep(set_time)
                            print()
                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                            def Add_Delay():
                                email_message = {"message": "I am sending an email message"}
                                return (f"An email {email_message} has been sent to {select_subcriber}\n")
                                            
                        elif action_Request== 3:
                            def Add_to_List():
                                Add_to_list_Action.append(select_subcriber)
                                return (f"Subscriber Added to List {Add_to_list_Action}")

                        elif action_Request == 4:
                            def Remove_from_List():
                                for x in range(len(Subscribers)):
                                    for key, value in Subscribers[x].items():
                                        if key == select_subcriber:
                                            removed_subscriber = Subscribers.pop(x)
                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                        elif action_Request == 5:
                            def Eject_from_Journey():
                                for x in range(len(Subscribers)):
                                    for key, value in Subscribers[x].items():
                                        if key == select_subcriber:
                                            ejected_subscriber = Subscribers.pop(x)
                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                        elif action_Request == 6:
                            def Apply_or_Remove_Tags():
                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                if select_choice == 1:
                                    add_tag = input("Please add a tag: e.g Marketing")
                                    for x in Subscribers:
                                        for key, value in x.items():
                                            if key == select_subcriber:
                                                value["Tags"] = {"tag1":add_tag}
                                            else:
                                                return ("Invalid Subscriber")
                                    return(f"Tag added to Subscriber {select_subcriber}, {Subscribers}")

                                elif select_choice == 2:
                                    for x in Subscribers:
                                        for key, value in x.items():
                                            if key == select_subcriber:
                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                        
                                                for key2, value2 in value.items():
                                                    if value2 == select_tag_to_remove:
                                                        del value[key2] 
                                                    else:
                                                        return ("Tag dosent exist")
                                            else:
                                                return("Invalid Subscriber")
                                                
                        elif action_Request == 7:
                            def Auto_Register():
                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                for x in Subscribers:
                                        for key, value in x.items():
                                            if key == select_subcriber:
                                                value["Webinar_Platform"] = "GotoWebinar"
                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                            else:
                                                return("Invalid Subscriber")        
                        else:
                            print("invalid selection please choose a valid input")

            elif select_list == 4:
                select_status = int(input("Please select Status: 1 for Is on List or 2 for Is not on List"))

                if select_status == 1:
                    print("Please Select any Subscriber:\n 1 for john@email.com \n 2 for sam@email.com \n 3 for great@email.com\n 4 for philip@email.com\n 5 for jake@email.com")

                    select_subcriber = input("Please select subscriber by inputing his email to check if he is on list e.g great@gmail.com")

                    if select_subcriber in Signed_in_Subscribers:
                        print("Subscriber is on List")
                        print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                        action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                        if action_Request == 1:
                            print()
                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                            def Send_email():
                                pass
                        
                        elif action_Request == 2:
                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                            sleep(set_time)
                            print()
                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                            def Add_Delay():
                                email_message = {"message": "I am sending an email message"}
                                return (f"An email {email_message} has been sent to {select_subcriber}\n")
                                            
                        elif action_Request== 3:
                            def Add_to_List():
                                Add_to_list_Action.append(select_subcriber)
                                return (f"Subscriber Added to List {Add_to_list_Action}")

                        elif action_Request == 4:
                            def Remove_from_List():
                                for x in range(len(Subscribers)):
                                    for key, value in Subscribers[x].items():
                                        if key == select_subcriber:
                                            removed_subscriber = Subscribers.pop(x)
                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                        elif action_Request == 5:
                            def Eject_from_Journey():
                                for x in range(len(Subscribers)):
                                    for key, value in Subscribers[x].items():
                                        if key == select_subcriber:
                                            ejected_subscriber = Subscribers.pop(x)
                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                        elif action_Request == 6:
                            def Apply_or_Remove_Tags():
                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                if select_choice == 1:
                                    add_tag = input("Please add a tag: e.g Marketing")
                                    for x in Subscribers:
                                        for key, value in x.items():
                                            if key == select_subcriber:
                                                value["Tags"] = {"tag1":add_tag}
                                            else:
                                                return ("Invalid Subscriber")
                                    return(f"Tag added to Subscriber {select_subcriber}, {Subscribers}")

                                elif select_choice == 2:
                                    for x in Subscribers:
                                        for key, value in x.items():
                                            if key == select_subcriber:
                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                        
                                                for key2, value2 in value.items():
                                                    if value2 == select_tag_to_remove:
                                                        del value[key2] 
                                                    else:
                                                        return ("Tag dosent exist")
                                            else:
                                                return("Invalid Subscriber")
                                                
                        elif action_Request == 7:
                            def Auto_Register():
                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                for x in Subscribers:
                                        for key, value in x.items():
                                            if key == select_subcriber:
                                                value["Webinar_Platform"] = "GotoWebinar"
                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                            else:
                                                return("Invalid Subscriber")        
                        else:
                            print("invalid selection please choose a valid input")
            else:
                print("Invalid Selection")

        elif condition_request == 3:
            pass
        elif condition_request == 4:
            pass
        elif condition_request == 5:
            pass
              
elif Trigger_request == 2:
    print()
    print("Please select List:\n 1 for Email List")
    select_list = int(input("Please Select List with Number Attached"))
    
    if select_list == 1:
        print()
        print("Please set Date to send email")
        now = datetime.datetime.now()
        Current_Date = f"{now.year}/{now.month}/{now.day}"
        time_zone = timezone.tzname
        print(f"The Current Date is {Current_Date}")
        day = int(input('Enter day in Numbers e.g. 25'))
        if day < 0 and day > 31:
            print("Invalid Date Please Input Valid Date")
            day = int(input('Enter day in Numbers e.g. 25'))
        elif day < now.day:
            print("That day is in the past Please Input Future day")
        else:
            Set_Date = f"{day}"
            month = int(input('Enter day in Numbers e.g. 9 which represents September'))
            if month < 0 and month > 12:
                print("Invalid Date Please Input Valid Date")
                month = int(input('Enter day in Numbers e.g. 9 which represents September'))
            elif month < now.month:
                print("That Month is in the past Please Input Future or Present Month")
            else:
                Set_Date = f"{month}/{day}"
                year = int(input('Enter year in Numbers e.g. 2022'))
                if month < 0:
                    print("Invalid Year Please Input Valid Year")
                    month = int(input('Enter day in Numbers e.g. 9 which represents September'))
                elif year < now.year:
                    print("That year is in the past Please Input Future or Present year")
                else:
                    Set_Date = f"{year}/{month}/{day}"
                    print(f"Your subscriberswill be added on this date {Set_Date}") 

                if Current_Date == Set_Date:
                        list_passed = []
                        for x in Emails:
                            list_passed.append(x)
                            print("Please Select Conditions to Pass Subriber for Futher Actions If the Meet The Condition:\n 1 for Campaign Status Condition\n 2 for On List or Segment Condition\n 3 for Has Visited Page Condition\n 4 for Check List Field Condition\n 5 for Purchase Status Condition \n 6 for Check Webinar Status Condition")

                        condition_request = int(input("Welcome Please Check the Output to Select a Condition to Apply With Number Attached:"))

                        if condition_request == 1:
                            print("Check for Campaign Status Selected\n")

                            print("Please Select any Email:\n 1 for john@email.com \n 2 for sam@email.com \n 3 for great@email.com\n 4 for philip@email.com\n 5 for jake@email.com")
                            select_email = int(input("Welcome Please Check the Output to Select an Email With Number Attached"))
                            if select_email == 1:
                                email = "john@email.com"
                                if email in Signed_in_Subscribers:
                                    for x in Signed_in_Subscribers:
                                        for key, value in x.items():
                                            if key == email:
                                                val = x[key]
                                                for key2 in val.keys():
                                                    if "Campaign_Status" in val:

                                                        print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                                                        action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                                                        if action_Request == 1:
                                                            print()
                                                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                                                            def Send_email():
                                                                pass
                                                        
                                                        elif action_Request == 2:
                                                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                                                            sleep(set_time)
                                                            print()
                                                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                                                            def Add_Delay():
                                                                email_message = {"message": "I am sending an email message"}
                                                                return (f"An email {email_message} has been sent to {email}\n")
                                                                            
                                                        elif action_Request== 3:
                                                            def Add_to_List():
                                                                Add_to_list_Action.append(email)
                                                                return (f"Subscriber Added to List {Add_to_list_Action}")

                                                        elif action_Request == 4:
                                                            def Remove_from_List():
                                                                for x in range(len(Subscribers)):
                                                                    for key, value in Subscribers[x].items():
                                                                        if key == email:
                                                                            removed_subscriber = Subscribers.pop(x)
                                                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                                                        elif action_Request == 5:
                                                            def Eject_from_Journey():
                                                                for x in range(len(Subscribers)):
                                                                    for key, value in Subscribers[x].items():
                                                                        if key == email:
                                                                            ejected_subscriber = Subscribers.pop(x)
                                                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                                                        elif action_Request == 6:
                                                            def Apply_or_Remove_Tags():
                                                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                                                if select_choice == 1:
                                                                    add_tag = input("Please add a tag: e.g Marketing")
                                                                    for x in Subscribers:
                                                                        for key, value in x.items():
                                                                            if key == email:
                                                                                value["Tags"] = {"tag1":add_tag}
                                                                            else:
                                                                                return ("Invalid Subscriber")
                                                                    return(f"Tag added to Subscriber {email}, {Subscribers}")

                                                                elif select_choice == 2:
                                                                    for x in Subscribers:
                                                                        for key, value in x.items():
                                                                            if key == email:
                                                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                                                        
                                                                                for key2, value2 in value.items():
                                                                                    if value2 == select_tag_to_remove:
                                                                                        del value[key2] 
                                                                                    else:
                                                                                        return ("Tag dosent exist")
                                                                            else:
                                                                                return("Invalid Subscriber")

                                                        elif action_Request == 7:
                                                            def Auto_Register():
                                                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                                                for x in Subscribers:
                                                                        for key, value in x.items():
                                                                            if key == email:
                                                                                value["Webinar_Platform"] = "GotoWebinar"
                                                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                                                            else:
                                                                                return("Invalid Subscriber")        
                                                        else:
                                                            print("invalid selection please choose a valid input")    
                                                            pass
                                                    else:
                                                        print("No Campaign_Status Detected")
                                else:
                                    print("User Not Signed_In")

                            elif select_email == 2:
                                email = "sam@email.com"
                                if email in Signed_in_Subscribers:
                                    for x in Signed_in_Subscribers:
                                        for key, value in x.items():
                                            if key == email:
                                                val = x[key]
                                                for key2 in val.keys():
                                                    if "Campaign_Status" in val:

                                                        print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                                                        action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                                                        if action_Request == 1:
                                                            print()
                                                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                                                            def Send_email():
                                                                pass
                                                        
                                                        elif action_Request == 2:
                                                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                                                            sleep(set_time)
                                                            print()
                                                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                                                            def Add_Delay():
                                                                email_message = {"message": "I am sending an email message"}
                                                                return (f"An email {email_message} has been sent to {email}\n")
                                                                            
                                                        elif action_Request== 3:
                                                            def Add_to_List():
                                                                Add_to_list_Action.append(email)
                                                                return (f"Subscriber Added to List {Add_to_list_Action}")

                                                        elif action_Request == 4:
                                                            def Remove_from_List():
                                                                for x in range(len(Subscribers)):
                                                                    for key, value in Subscribers[x].items():
                                                                        if key == email:
                                                                            removed_subscriber = Subscribers.pop(x)
                                                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                                                        elif action_Request == 5:
                                                            def Eject_from_Journey():
                                                                for x in range(len(Subscribers)):
                                                                    for key, value in Subscribers[x].items():
                                                                        if key == email:
                                                                            ejected_subscriber = Subscribers.pop(x)
                                                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                                                        elif action_Request == 6:
                                                            def Apply_or_Remove_Tags():
                                                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                                                if select_choice == 1:
                                                                    add_tag = input("Please add a tag: e.g Marketing")
                                                                    for x in Subscribers:
                                                                        for key, value in x.items():
                                                                            if key == email:
                                                                                value["Tags"] = {"tag1":add_tag}
                                                                            else:
                                                                                return ("Invalid Subscriber")
                                                                    return(f"Tag added to Subscriber {email}, {Subscribers}")

                                                                elif select_choice == 2:
                                                                    for x in Subscribers:
                                                                        for key, value in x.items():
                                                                            if key == email:
                                                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                                                        
                                                                                for key2, value2 in value.items():
                                                                                    if value2 == select_tag_to_remove:
                                                                                        del value[key2] 
                                                                                    else:
                                                                                        return ("Tag dosent exist")
                                                                            else:
                                                                                return("Invalid Subscriber")
                                                                                
                                                        elif action_Request == 7:
                                                            def Auto_Register():
                                                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                                                for x in Subscribers:
                                                                        for key, value in x.items():
                                                                            if key == email:
                                                                                value["Webinar_Platform"] = "GotoWebinar"
                                                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                                                            else:
                                                                                return("Invalid Subscriber")        
                                                        else:
                                                            print("invalid selection please choose a valid input")    
                                                            pass
                                                    else:
                                                        print("No Campaign_Status Detected")
                                else:
                                    print("User Not Signed_In")


                            elif select_email == 3:
                                email = "great@email.com"
                                if email in Signed_in_Subscribers:
                                    for x in Signed_in_Subscribers:
                                        for key, value in x.items():
                                            if key == email:
                                                val = x[key]
                                                for key2 in val.keys():
                                                    if "Campaign_Status" in val:

                                                        print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                                                        action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                                                        if action_Request == 1:
                                                            print()
                                                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                                                            def Send_email():
                                                                pass
                                                        
                                                        elif action_Request == 2:
                                                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                                                            sleep(set_time)
                                                            print()
                                                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                                                            def Add_Delay():
                                                                email_message = {"message": "I am sending an email message"}
                                                                return (f"An email {email_message} has been sent to {email}\n")
                                                                            
                                                        elif action_Request== 3:
                                                            def Add_to_List():
                                                                Add_to_list_Action.append(email)
                                                                return (f"Subscriber Added to List {Add_to_list_Action}")

                                                        elif action_Request == 4:
                                                            def Remove_from_List():
                                                                for x in range(len(Subscribers)):
                                                                    for key, value in Subscribers[x].items():
                                                                        if key == email:
                                                                            removed_subscriber = Subscribers.pop(x)
                                                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                                                        elif action_Request == 5:
                                                            def Eject_from_Journey():
                                                                for x in range(len(Subscribers)):
                                                                    for key, value in Subscribers[x].items():
                                                                        if key == email:
                                                                            ejected_subscriber = Subscribers.pop(x)
                                                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                                                        elif action_Request == 6:
                                                            def Apply_or_Remove_Tags():
                                                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                                                if select_choice == 1:
                                                                    add_tag = input("Please add a tag: e.g Marketing")
                                                                    for x in Subscribers:
                                                                        for key, value in x.items():
                                                                            if key == email:
                                                                                value["Tags"] = {"tag1":add_tag}
                                                                            else:
                                                                                return ("Invalid Subscriber")
                                                                    return(f"Tag added to Subscriber {email}, {Subscribers}")

                                                                elif select_choice == 2:
                                                                    for x in Subscribers:
                                                                        for key, value in x.items():
                                                                            if key == email:
                                                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                                                        
                                                                                for key2, value2 in value.items():
                                                                                    if value2 == select_tag_to_remove:
                                                                                        del value[key2] 
                                                                                    else:
                                                                                        return ("Tag dosent exist")
                                                                            else:
                                                                                return("Invalid Subscriber")
                                                                                
                                                        elif action_Request == 7:
                                                            def Auto_Register():
                                                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                                                for x in Subscribers:
                                                                        for key, value in x.items():
                                                                            if key == email:
                                                                                value["Webinar_Platform"] = "GotoWebinar"
                                                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                                                            else:
                                                                                return("Invalid Subscriber")        
                                                        else:
                                                            print("invalid selection please choose a valid input")    
                                                            pass
                                                    else:
                                                        print("No Campaign_Status Detected")
                                else:
                                    print("User Not Signed_In")

                            elif select_email == 4:
                                email = "philip@email.com"
                                if email in Signed_in_Subscribers:
                                    for x in Signed_in_Subscribers:
                                        for key, value in x.items():
                                            if key == email:
                                                val = x[key]
                                                for key2 in val.keys():
                                                    if "Campaign_Status" in val:

                                                        print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                                                        action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                                                        if action_Request == 1:
                                                            print()
                                                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                                                            def Send_email():
                                                                pass
                                                        
                                                        elif action_Request == 2:
                                                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                                                            sleep(set_time)
                                                            print()
                                                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                                                            def Add_Delay():
                                                                email_message = {"message": "I am sending an email message"}
                                                                return (f"An email {email_message} has been sent to {email}\n")
                                                                            
                                                        elif action_Request== 3:
                                                            def Add_to_List():
                                                                Add_to_list_Action.append(email)
                                                                return (f"Subscriber Added to List {Add_to_list_Action}")

                                                        elif action_Request == 4:
                                                            def Remove_from_List():
                                                                for x in range(len(Subscribers)):
                                                                    for key, value in Subscribers[x].items():
                                                                        if key == email:
                                                                            removed_subscriber = Subscribers.pop(x)
                                                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                                                        elif action_Request == 5:
                                                            def Eject_from_Journey():
                                                                for x in range(len(Subscribers)):
                                                                    for key, value in Subscribers[x].items():
                                                                        if key == email:
                                                                            ejected_subscriber = Subscribers.pop(x)
                                                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                                                        elif action_Request == 6:
                                                            def Apply_or_Remove_Tags():
                                                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                                                if select_choice == 1:
                                                                    add_tag = input("Please add a tag: e.g Marketing")
                                                                    for x in Subscribers:
                                                                        for key, value in x.items():
                                                                            if key == email:
                                                                                value["Tags"] = {"tag1":add_tag}
                                                                            else:
                                                                                return ("Invalid Subscriber")
                                                                    return(f"Tag added to Subscriber {email}, {Subscribers}")

                                                                elif select_choice == 2:
                                                                    for x in Subscribers:
                                                                        for key, value in x.items():
                                                                            if key == email:
                                                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                                                        
                                                                                for key2, value2 in value.items():
                                                                                    if value2 == select_tag_to_remove:
                                                                                        del value[key2] 
                                                                                    else:
                                                                                        return ("Tag dosent exist")
                                                                            else:
                                                                                return("Invalid Subscriber")
                                                                                
                                                        elif action_Request == 7:
                                                            def Auto_Register():
                                                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                                                for x in Subscribers:
                                                                        for key, value in x.items():
                                                                            if key == email:
                                                                                value["Webinar_Platform"] = "GotoWebinar"
                                                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                                                            else:
                                                                                return("Invalid Subscriber")        
                                                        else:
                                                            print("invalid selection please choose a valid input")    
                                                            pass
                                                    else:
                                                        print("No Campaign_Status Detected")
                                else:
                                    print("User Not Signed_In")

                            elif select_email == 5:
                                email = "jake@email.com"
                                if email in Signed_in_Subscribers:
                                    for x in Signed_in_Subscribers:
                                        for key, value in x.items():
                                            if key == email:
                                                val = x[key]
                                                for key2 in val.keys():
                                                    if "Campaign_Status" in val:

                                                        print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                                                    action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                                                    if action_Request == 1:
                                                            print()
                                                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                                                            def Send_email():
                                                                pass
                                                        
                                                    elif action_Request == 2:
                                                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                                                            sleep(set_time)
                                                            print()
                                                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                                                            def Add_Delay():
                                                                email_message = {"message": "I am sending an email message"}
                                                                return (f"An email {email_message} has been sent to {email}\n")
                                                                            
                                                    elif action_Request== 3:
                                                            def Add_to_List():
                                                                Add_to_list_Action.append(email)
                                                                return (f"Subscriber Added to List {Add_to_list_Action}")

                                                    elif action_Request == 4:
                                                            def Remove_from_List():
                                                                for x in range(len(Subscribers)):
                                                                    for key, value in Subscribers[x].items():
                                                                        if key == email:
                                                                            removed_subscriber = Subscribers.pop(x)
                                                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                                                    elif action_Request == 5:
                                                            def Eject_from_Journey():
                                                                for x in range(len(Subscribers)):
                                                                    for key, value in Subscribers[x].items():
                                                                        if key == email:
                                                                            ejected_subscriber = Subscribers.pop(x)
                                                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                                                    elif action_Request == 6:
                                                            def Apply_or_Remove_Tags():
                                                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                                                if select_choice == 1:
                                                                    add_tag = input("Please add a tag: e.g Marketing")
                                                                    for x in Subscribers:
                                                                        for key, value in x.items():
                                                                            if key == email:
                                                                                value["Tags"] = {"tag1":add_tag}
                                                                            else:
                                                                                return ("Invalid Subscriber")
                                                                    return(f"Tag added to Subscriber {email}, {Subscribers}")

                                                                elif select_choice == 2:
                                                                    for x in Subscribers:
                                                                        for key, value in x.items():
                                                                            if key == email:
                                                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                                                        
                                                                                for key2, value2 in value.items():
                                                                                    if value2 == select_tag_to_remove:
                                                                                        del value[key2] 
                                                                                    else:
                                                                                        return ("Tag dosent exist")
                                                                            else:
                                                                                return("Invalid Subscriber")
                                                                                
                                                    elif action_Request == 7:
                                                            def Auto_Register():
                                                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                                                for x in Subscribers:
                                                                        for key, value in x.items():
                                                                            if key == email:
                                                                                value["Webinar_Platform"] = "GotoWebinar"
                                                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                                                            else:
                                                                                return("Invalid Subscriber")        
                                                    else:
                                                            print("invalid selection please choose a valid input")    
                                                            pass
                                                else:
                                                    print("No Campaign_Status Detected")
                                else:
                                    print("User Not Signed_In")

                        elif condition_request == 2:
                            
                            print("Please Select any List to Check On List Condition:\n 1 for Subscribers List \n 2 for Emails List \n 3 for Add_To_List_Action_list\n 4 for Signed_in_Subscribers_List")

                            select_list = int(input("Welcome Please Check the Output to Select a List With Number Attached"))
                            if select_list == 1:
                            
                                select_status = int(input("Please select Status: 1 for Is on List or 2 for Is not on List"))

                                if select_status == 1:
                                    print("Please Select any Subscriber:\n 1 for john@email.com \n 2 for sam@email.com \n 3 for great@email.com\n 4 for philip@email.com\n 5 for jake@email.com")
                                    select_subcriber = input("Please select subscriber by inputing his email to check if he is on list e.g great@gmail.com")

                                    for x in Subscribers:
                                        for key , value in x.items():
                                            if key == select_subcriber:
                                                print("Subscriber is on List")
                                                print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                                                action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                                                if action_Request == 1:
                                                    print()
                                                    print("The Send Email Action has Completed Please Continue with your Work Flow")
                                                    def Send_email():
                                                        pass
                                                
                                                elif action_Request == 2:
                                                    set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                                                    sleep(set_time)
                                                    print()
                                                    print("The Add Delay Action has Completed Please Continue with your Work Flow")
                                                    def Add_Delay(select_subcriber):
                                                        email_message = {"message": "I am sending an email message"}
                                                        return (f"An email {email_message} has been sent to {select_subcriber}\n")
                                                                    
                                                elif action_Request== 3:
                                                    def Add_to_List():
                                                        Add_to_list_Action.append(select_subcriber)
                                                        return (f"Subscriber Added to List {Add_to_list_Action}")

                                                elif action_Request == 4:
                                                    def Remove_from_List():
                                                        for x in range(len(Subscribers)):
                                                            for key, value in Subscribers[x].items():
                                                                if key == select_subcriber:
                                                                    removed_subscriber = Subscribers.pop(x)
                                                        return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                                                elif action_Request == 5:
                                                    def Eject_from_Journey():
                                                        for x in range(len(Subscribers)):
                                                            for key, value in Subscribers[x].items():
                                                                if key == select_subcriber:
                                                                    ejected_subscriber = Subscribers.pop(x)
                                                        return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                                                elif action_Request == 6:
                                                    def Apply_or_Remove_Tags():
                                                        select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                                        if select_choice == 1:
                                                            add_tag = input("Please add a tag: e.g Marketing")
                                                            for x in Subscribers:
                                                                for key, value in x.items():
                                                                    if key == select_subcriber:
                                                                        value["Tags"] = {"tag1":add_tag}
                                                                    else:
                                                                        return ("Invalid Subscriber")
                                                            return(f"Tag added to Subscriber {select_subcriber}, {Subscribers}")

                                                        elif select_choice == 2:
                                                            for x in Subscribers:
                                                                for key, value in x.items():
                                                                    if key == select_subcriber:
                                                                        select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                                                
                                                                        for key2, value2 in value.items():
                                                                            if value2 == select_tag_to_remove:
                                                                                del value[key2] 
                                                                            else:
                                                                                return ("Tag dosent exist")
                                                                    else:
                                                                        return("Invalid Subscriber")
                                                                        
                                                elif action_Request == 7:
                                                    def Auto_Register():
                                                        add_upcoming_webinar = input("Please add any upcoming webinar")
                                                        for x in Subscribers:
                                                                for key, value in x.items():
                                                                    if key == select_subcriber:
                                                                        value["Webinar_Platform"] = "GotoWebinar"
                                                                        value["Upcoming_Webinar"] = add_upcoming_webinar
                                                                    else:
                                                                        return("Invalid Subscriber")        
                                                else:
                                                    print("invalid selection please choose a valid input")

                                elif select_status == 2:
                                    print("Please Select any Subscriber:\n 1 for john@email.com \n 2 for sam@email.com \n 3 for great@email.com\n 4 for philip@email.com\n 5 for jake@email.com")
                                    select_subcriber = input("Please select subscriber by inputing his email to check if he is on list e.g great@gmail.com")

                                    for x in Subscribers:
                                        for key , value in x.items():
                                            if key != select_subcriber:
                                                print("User not on list")

                            elif select_list == 2:
                                select_status = int(input("Please select Status: 1 for Is on List or 2 for Is not on List"))

                                if select_status == 1:
                                    print("Please Select any Subscriber:\n 1 for john@email.com \n 2 for sam@email.com \n 3 for great@email.com\n 4 for philip@email.com\n 5 for jake@email.com")

                                    select_subcriber = input("Please select subscriber by inputing his email to check if he is on list e.g great@gmail.com")

                                    if select_subcriber in Emails:
                                        print("Subscriber is on List")
                                        print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                                        action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                                        if action_Request == 1:
                                            print()
                                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                                            def Send_email():
                                                pass
                                        
                                        elif action_Request == 2:
                                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                                            sleep(set_time)
                                            print()
                                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                                            def Add_Delay():
                                                email_message = {"message": "I am sending an email message"}
                                                return (f"An email {email_message} has been sent to {select_subcriber}\n")
                                                            
                                        elif action_Request== 3:
                                            def Add_to_List():
                                                Add_to_list_Action.append(select_subcriber)
                                                return (f"Subscriber Added to List {Add_to_list_Action}")

                                        elif action_Request == 4:
                                            def Remove_from_List():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == select_subcriber:
                                                            removed_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                                        elif action_Request == 5:
                                            def Eject_from_Journey():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == select_subcriber:
                                                            ejected_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                                        elif action_Request == 6:
                                            def Apply_or_Remove_Tags():
                                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                                if select_choice == 1:
                                                    add_tag = input("Please add a tag: e.g Marketing")
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == select_subcriber:
                                                                value["Tags"] = {"tag1":add_tag}
                                                            else:
                                                                return ("Invalid Subscriber")
                                                    return(f"Tag added to Subscriber {select_subcriber}, {Subscribers}")

                                                elif select_choice == 2:
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == select_subcriber:
                                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                                        
                                                                for key2, value2 in value.items():
                                                                    if value2 == select_tag_to_remove:
                                                                        del value[key2] 
                                                                    else:
                                                                        return ("Tag dosent exist")
                                                            else:
                                                                return("Invalid Subscriber")
                                                                
                                        elif action_Request == 7:
                                            def Auto_Register():
                                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                                for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == select_subcriber:
                                                                value["Webinar_Platform"] = "GotoWebinar"
                                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                                            else:
                                                                return("Invalid Subscriber")        
                                        else:
                                            print("invalid selection please choose a valid input")

                            elif select_list == 3:
                                select_status = int(input("Please select Status: 1 for Is on List or 2 for Is not on List"))

                                if select_status == 1:
                                    print("Please Select any Subscriber:\n 1 for john@email.com \n 2 for sam@email.com \n 3 for great@email.com\n 4 for philip@email.com\n 5 for jake@email.com")

                                    select_subcriber = input("Please select subscriber by inputing his email to check if he is on list e.g great@gmail.com")

                                    if select_subcriber in Add_to_list_Action:
                                        print("Subscriber is on List")
                                        print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                                        action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                                        if action_Request == 1:
                                            print()
                                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                                            def Send_email():
                                                pass
                                        
                                        elif action_Request == 2:
                                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                                            sleep(set_time)
                                            print()
                                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                                            def Add_Delay():
                                                email_message = {"message": "I am sending an email message"}
                                                return (f"An email {email_message} has been sent to {select_subcriber}\n")
                                                            
                                        elif action_Request== 3:
                                            def Add_to_List():
                                                Add_to_list_Action.append(select_subcriber)
                                                return (f"Subscriber Added to List {Add_to_list_Action}")

                                        elif action_Request == 4:
                                            def Remove_from_List():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == select_subcriber:
                                                            removed_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                                        elif action_Request == 5:
                                            def Eject_from_Journey():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == select_subcriber:
                                                            ejected_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                                        elif action_Request == 6:
                                            def Apply_or_Remove_Tags():
                                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                                if select_choice == 1:
                                                    add_tag = input("Please add a tag: e.g Marketing")
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == select_subcriber:
                                                                value["Tags"] = {"tag1":add_tag}
                                                            else:
                                                                return ("Invalid Subscriber")
                                                    return(f"Tag added to Subscriber {select_subcriber}, {Subscribers}")

                                                elif select_choice == 2:
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == select_subcriber:
                                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                                        
                                                                for key2, value2 in value.items():
                                                                    if value2 == select_tag_to_remove:
                                                                        del value[key2] 
                                                                    else:
                                                                        return ("Tag dosent exist")
                                                            else:
                                                                return("Invalid Subscriber")
                                                                
                                        elif action_Request == 7:
                                            def Auto_Register():
                                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                                for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == select_subcriber:
                                                                value["Webinar_Platform"] = "GotoWebinar"
                                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                                            else:
                                                                return("Invalid Subscriber")        
                                        else:
                                            print("invalid selection please choose a valid input")

                            elif select_list == 4:
                                select_status = int(input("Please select Status: 1 for Is on List or 2 for Is not on List"))

                                if select_status == 1:
                                    print("Please Select any Subscriber:\n 1 for john@email.com \n 2 for sam@email.com \n 3 for great@email.com\n 4 for philip@email.com\n 5 for jake@email.com")

                                    select_subcriber = input("Please select subscriber by inputing his email to check if he is on list e.g great@gmail.com")

                                    if select_subcriber in Signed_in_Subscribers:
                                        print("Subscriber is on List")
                                        print(" Welcome to Actions Section Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags or Remove Tags\n 7 for Auto-Register")

                                        action_Request = int(input("Welcome Please Check the Output to Select an Action Option With Number Attached:"))

                                        if action_Request == 1:
                                            print()
                                            print("The Send Email Action has Completed Please Continue with your Work Flow")
                                            def Send_email():
                                                pass
                                        
                                        elif action_Request == 2:
                                            set_time = float(input("Please set time delay in form of seconds e.g 60.0 which is 60 secs and also 1 minute"))
                                            sleep(set_time)
                                            print()
                                            print("The Add Delay Action has Completed Please Continue with your Work Flow")
                                            def Add_Delay():
                                                email_message = {"message": "I am sending an email message"}
                                                return (f"An email {email_message} has been sent to {select_subcriber}\n")
                                                            
                                        elif action_Request== 3:
                                            def Add_to_List():
                                                Add_to_list_Action.append(select_subcriber)
                                                return (f"Subscriber Added to List {Add_to_list_Action}")

                                        elif action_Request == 4:
                                            def Remove_from_List():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == select_subcriber:
                                                            removed_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been removed from list {Subscribers}")

                                        elif action_Request == 5:
                                            def Eject_from_Journey():
                                                for x in range(len(Subscribers)):
                                                    for key, value in Subscribers[x].items():
                                                        if key == select_subcriber:
                                                            ejected_subscriber = Subscribers.pop(x)
                                                return(f"Subscriber {removed_subscriber} has been Ejected from Journey Subscriber is still eligible to begin journey again")

                                        elif action_Request == 6:
                                            def Apply_or_Remove_Tags():
                                                select_choice =int(input("Please Select either: 1 for Apply tags or  2 for Remove tags"))
                                                if select_choice == 1:
                                                    add_tag = input("Please add a tag: e.g Marketing")
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == select_subcriber:
                                                                value["Tags"] = {"tag1":add_tag}
                                                            else:
                                                                return ("Invalid Subscriber")
                                                    return(f"Tag added to Subscriber {select_subcriber}, {Subscribers}")

                                                elif select_choice == 2:
                                                    for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == select_subcriber:
                                                                select_tag_to_remove = input(f"Please select tags to be removed from {value}")
                                                        
                                                                for key2, value2 in value.items():
                                                                    if value2 == select_tag_to_remove:
                                                                        del value[key2] 
                                                                    else:
                                                                        return ("Tag dosent exist")
                                                            else:
                                                                return("Invalid Subscriber")
                                                                
                                        elif action_Request == 7:
                                            def Auto_Register():
                                                add_upcoming_webinar = input("Please add any upcoming webinar")
                                                for x in Subscribers:
                                                        for key, value in x.items():
                                                            if key == select_subcriber:
                                                                value["Webinar_Platform"] = "GotoWebinar"
                                                                value["Upcoming_Webinar"] = add_upcoming_webinar
                                                            else:
                                                                return("Invalid Subscriber")        
                                        else:
                                            print("invalid selection please choose a valid input")
                            else:
                                print("Invalid Selection")

                        elif condition_request == 3:
                            pass
                        elif condition_request == 4:
                            pass
                        elif condition_request == 5:
                            pass
                           
elif Trigger_request == 3:
        pass
elif Trigger_request == 4:
        print()
        print("Please select List:\n 1 for Subscribers List\n 2 for Email List")
        select_list_to_remove_from = int(input("Please Select List with Number Attached"))
        if select_list_to_remove_from == 1:
            removed_subscriber = Subscribers.pop()
            print("Please select:\n 1 for Send Email Action\n 2 Add Delay Action\n 3 for Add to List Action\n 4 for Removed from List Action\n 5 for Eject from Journey\n 6 for Apply Tags\n 7 for Remove Tags\n 8 for Auto-Register")
            action_Request = int(input("Please Select Action With Number Attached:"))
            if action_Request == 1:
                def Send_email():
                    pass
            elif action_Request == 2:
                def Add_Delay(Emails):
                    pass
            elif action_Request== 3:
                def Add_to_List(Emails):
                    pass
            elif action_Request == 4:
                def Remove_from_List(Emails):
                    pass
            elif action_Request == 5:
                def Eject_from_Journey(Emails):
                    pass
            elif action_Request == 6:
                def Apply_Tags(Emails):
                    pass
            elif action_Request == 7:
                def Remove_Tags(Emails):
                    pass
            elif action_Request == 8:
                def Auto_Register(Emails):
                    pass
            else:
                print("invalid selection please choose a valid input")

        elif select_list_to_remove_from == 2:
            removed_subscriber_email = Emails.pop()
        else:
            print("invalid selection please choose a valid input")    
elif Trigger_request == 5:
        pass
elif Trigger_request == 6:
        pass
elif Trigger_request == 7:
        pass
else:
    print('Please Select A valid Option From the List of Triggers Using Numbers e.g Selecting 4 will trigger Remove from List Trigger')

# Send_email()
# Out:
# WELCOME TO WORKFLOW ENGINE
#  Welcome to Triggers Section Please select:
#  1 for Opt-in Trigger
#  2 for Time Trigger
#  3 for Campaign Trigger
#  4 for Removed from List Trigger
#  5 for Purchase Activity Trigger
#  6 for Page Visited Trigger
#  7 for Register Webinar or Attend Webinar
#
# The Opt-In Trigger has been Triggered Please Continue with your Work Flow
# Please Select Conditions to Pass Subriber for Futher Actions If the Meet The Condition:
#  1 for Campaign Status Condition
#  2 for On List or Segment Condition
#  3 for Has Visited Page Condition
#  4 for Check List Field Condition
#  5 for Purchase Status Condition
#  6 for Check Webinar Status Condition
# Please Select any List to Check On List Condition:
#  1 for Subscribers List
#  2 for Emails List
#  3 for Add_To_List_Action_list
#  4 for Signed_in_Subscribers_List
# Please Select any Subscriber:
#  1 for john@email.com
#  2 for sam@email.com
#  3 for great@email.com
#  4 for philip@email.com
# ...

# %%
tz = datetime.timezone.tzname
print(tz)
# Out:
# <method 'tzname' of 'datetime.timezone' objects>
